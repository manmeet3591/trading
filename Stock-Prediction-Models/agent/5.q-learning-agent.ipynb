# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# Out:
# /home/manmeet/anaconda3/envs/drl/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/manmeet/anaconda3/envs/drl/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/manmeet/anaconda3/envs/drl/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/manmeet/anaconda3/envs/drl/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/manmeet/anaconda3/envs/drl/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/manmeet/anaconda3/envs/drl/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /home/manmeet/anaconda3/envs/drl/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/manmeet/anaconda3/envs/drl/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/manmeet/anaconda3/envs/drl/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/manmeet/anaconda3/envs/drl/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/manmeet/anaconda3/envs/drl/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/manmeet/anaconda3/envs/drl/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
df = pd.read_csv('../dataset/GOOG-year.csv')
df = pd.read_csv('../dataset/BTC-USD.csv')
df.head()
# Out:
#          Date          Open          High           Low         Close  \
# 0  2020-07-25   9539.485352   9704.556641   9530.211914   9677.113281
# 1  2020-07-26   9680.234375  10023.807617   9652.847656   9905.166992
# 2  2020-07-27   9905.217773  11298.221680   9903.969727  10990.873047
# 3  2020-07-28  11017.463867  11204.327148  10632.631836  10912.823242
# 4  2020-07-29  10912.953125  11304.397461  10856.141602  11100.467773
#
#       Adj Close        Volume
# 0   9677.113281  1.661007e+10
# 1   9905.166992  2.050800e+10
# 2  10990.873047  3.535975e+10
# 3  10912.823242  2.876655e+10
# 4  11100.467773  2.461725e+10

# %%
from collections import deque
import random


class Agent:
    def __init__(self, state_size, window_size, trend, skip, batch_size):
        self.state_size = state_size
        self.window_size = window_size
        self.half_window = window_size // 2
        self.trend = trend
        self.skip = skip
        self.action_size = 3
        self.batch_size = batch_size
        self.memory = deque(maxlen = 1000)
        self.inventory = []

        self.gamma = 0.95
        self.epsilon = 0.5
        self.epsilon_min = 0.01
        self.epsilon_decay = 0.999

        tf.reset_default_graph()
        self.sess = tf.InteractiveSession()
        self.X = tf.placeholder(tf.float32, [None, self.state_size])
        self.Y = tf.placeholder(tf.float32, [None, self.action_size])
        feed = tf.layers.dense(self.X, 256, activation = tf.nn.relu)
        self.logits = tf.layers.dense(feed, self.action_size)
        self.cost = tf.reduce_mean(tf.square(self.Y - self.logits))
        self.optimizer = tf.train.GradientDescentOptimizer(1e-5).minimize(
            self.cost
        )
        self.sess.run(tf.global_variables_initializer())

    def act(self, state):
        if random.random() <= self.epsilon:
            return random.randrange(self.action_size)
        return np.argmax(
            self.sess.run(self.logits, feed_dict = {self.X: state})[0]
        )
    
    def get_state(self, t):
        window_size = self.window_size + 1
        d = t - window_size + 1
        block = self.trend[d : t + 1] if d >= 0 else -d * [self.trend[0]] + self.trend[0 : t + 1]
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])
        return np.array([res])

    def replay(self, batch_size):
        mini_batch = []
        l = len(self.memory)
        for i in range(l - batch_size, l):
            mini_batch.append(self.memory[i])
        replay_size = len(mini_batch)
        X = np.empty((replay_size, self.state_size))
        Y = np.empty((replay_size, self.action_size))
        states = np.array([a[0][0] for a in mini_batch])
        new_states = np.array([a[3][0] for a in mini_batch])
        Q = self.sess.run(self.logits, feed_dict = {self.X: states})
        Q_new = self.sess.run(self.logits, feed_dict = {self.X: new_states})
        for i in range(len(mini_batch)):
            state, action, reward, next_state, done = mini_batch[i]
            target = Q[i]
            target[action] = reward
            if not done:
                target[action] += self.gamma * np.amax(Q_new[i])
            X[i] = state
            Y[i] = target
        cost, _ = self.sess.run(
            [self.cost, self.optimizer], feed_dict = {self.X: X, self.Y: Y}
        )
        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay
        return cost
    
    def buy(self, initial_money):
        starting_money = initial_money
        states_sell = []
        states_buy = []
        inventory = []
        state = self.get_state(0)
        for t in range(0, len(self.trend) - 1, self.skip):
            action = self.act(state)
            next_state = self.get_state(t + 1)
            
            if action == 1 and initial_money >= self.trend[t] and t < (len(self.trend) - self.half_window):
                inventory.append(self.trend[t])
                initial_money -= self.trend[t]
                states_buy.append(t)
                print('day %d: buy 1 unit at price %f, total balance %f'% (t, self.trend[t], initial_money))
                
                
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                initial_money += self.trend[t]
                states_sell.append(t)
                try:
                    invest = ((close[t] - bought_price) / bought_price) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell 1 unit at price %f, investment %f %%, total balance %f,'
                    % (t, close[t], invest, initial_money)
                )
            
            state = next_state
        invest = ((initial_money - starting_money) / starting_money) * 100
        total_gains = initial_money - starting_money
        return states_buy, states_sell, total_gains, invest
        
    def train(self, iterations, checkpoint, initial_money):
        for i in range(iterations):
            total_profit = 0
            inventory = []
            state = self.get_state(0)
            starting_money = initial_money
            for t in range(0, len(self.trend) - 1, self.skip):
                action = self.act(state)
                next_state = self.get_state(t + 1)
                
                if action == 1 and starting_money >= self.trend[t] and t < (len(self.trend) - self.half_window):
                    inventory.append(self.trend[t])
                    starting_money -= self.trend[t]
                
                elif action == 2 and len(inventory) > 0:
                    bought_price = inventory.pop(0)
                    total_profit += self.trend[t] - bought_price
                    starting_money += self.trend[t]
                    
                invest = ((starting_money - initial_money) / initial_money)
                self.memory.append((state, action, invest, 
                                    next_state, starting_money < initial_money))
                state = next_state
                batch_size = min(self.batch_size, len(self.memory))
                cost = self.replay(batch_size)
            if (i+1) % checkpoint == 0:
                print('epoch: %d, total rewards: %f.3, cost: %f, total money: %f'%(i + 1, total_profit, cost,
                                                                                  starting_money))

# %%
close = df.Close.values.tolist()
initial_money = 1000000
window_size = 30
skip = 1
batch_size = 32
agent = Agent(state_size = window_size, 
              window_size = window_size, 
              trend = close, 
              skip = skip, 
              batch_size = batch_size)
agent.train(iterations = 200, checkpoint = 10, initial_money = initial_money)
# Out:
# WARNING:tensorflow:From <ipython-input-3-9934fc4f9176>:26: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dense instead.
# WARNING:tensorflow:From /home/manmeet/anaconda3/envs/drl/lib/python3.6/site-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# epoch: 10, total rewards: 55973.897461.3, cost: nan, total money: 1055973.897461
# epoch: 20, total rewards: 25344.496093.3, cost: nan, total money: 909365.001952
# epoch: 30, total rewards: 0.000000.3, cost: nan, total money: 1000000.000000
# epoch: 40, total rewards: 0.000000.3, cost: nan, total money: 966527.367187
# epoch: 50, total rewards: 0.000000.3, cost: nan, total money: 1000000.000000
# epoch: 60, total rewards: 686.911133.3, cost: nan, total money: 942221.737305
# epoch: 70, total rewards: 0.000000.3, cost: nan, total money: 943951.062500
# epoch: 80, total rewards: 0.000000.3, cost: nan, total money: 946898.027344
# epoch: 90, total rewards: 40054.832031.3, cost: nan, total money: 1005405.187500
# epoch: 100, total rewards: 4310.316407.3, cost: nan, total money: 1004310.316407
# epoch: 110, total rewards: 312.266602.3, cost: nan, total money: 1000312.266602
# epoch: 120, total rewards: 22143.822266.3, cost: nan, total money: 1022143.822266
# epoch: 130, total rewards: 4979.982422.3, cost: nan, total money: 1004979.982422
# epoch: 140, total rewards: 0.000000.3, cost: nan, total money: 950294.667969
# epoch: 150, total rewards: 0.000000.3, cost: nan, total money: 909546.617187

# %%
states_buy, states_sell, total_gains, invest = agent.buy(initial_money = initial_money)
# Out:
# day 1: buy 1 unit at price 762.130005, total balance 9237.869995
# day 2, sell 1 unit at price 762.020020, investment -0.014431 %, total balance 9999.890015,
# day 6: buy 1 unit at price 762.559998, total balance 9237.330017
# day 7: buy 1 unit at price 754.020020, total balance 8483.309997
# day 8: buy 1 unit at price 736.080017, total balance 7747.229980
# day 11: buy 1 unit at price 771.229980, total balance 6976.000000
# day 12: buy 1 unit at price 760.539978, total balance 6215.460022
# day 15, sell 1 unit at price 760.989990, investment -0.205886 %, total balance 6976.450012,
# day 16, sell 1 unit at price 761.679993, investment 1.015885 %, total balance 7738.130005,
# day 18: buy 1 unit at price 770.840027, total balance 6967.289978
# day 19: buy 1 unit at price 758.039978, total balance 6209.250000
# day 20, sell 1 unit at price 747.919983, investment 1.608516 %, total balance 6957.169983,
# day 22: buy 1 unit at price 762.520020, total balance 6194.649963
# day 23, sell 1 unit at price 759.109985, investment -1.571515 %, total balance 6953.759948,
# day 27, sell 1 unit at price 789.270020, investment 3.777585 %, total balance 7743.029968,
# day 28: buy 1 unit at price 796.099976, total balance 6946.929992
# day 29: buy 1 unit at price 797.070007, total balance 6149.859985
# day 30: buy 1 unit at price 797.849976, total balance 5352.010009
# day 33, sell 1 unit at price 796.419983, investment 3.318452 %, total balance 6148.429992,
# day 34, sell 1 unit at price 794.559998, investment 4.817690 %, total balance 6942.989990,
# day 35, sell 1 unit at price 791.260010, investment 3.769080 %, total balance 7734.250000,
# day 36, sell 1 unit at price 789.909973, investment -0.777541 %, total balance 8524.159973,
# day 40: buy 1 unit at price 771.820007, total balance 7752.339966
# day 42: buy 1 unit at price 786.900024, total balance 6965.439942
# day 45, sell 1 unit at price 806.650024, investment 1.201904 %, total balance 7772.089966,
# day 46, sell 1 unit at price 804.789978, investment 0.869838 %, total balance 8576.879944,
# day 48, sell 1 unit at price 806.359985, investment 4.475134 %, total balance 9383.239929,
# day 49, sell 1 unit at price 807.880005, investment 2.666156 %, total balance 10191.119934,
# day 50: buy 1 unit at price 804.609985, total balance 9386.509949
# day 51: buy 1 unit at price 806.070007, total balance 8580.439942
# day 52, sell 1 unit at price 802.174988, investment -0.302631 %, total balance 9382.614930,
# day 53, sell 1 unit at price 805.020020, investment -0.130260 %, total balance 10187.634950,
# day 61: buy 1 unit at price 795.695007, total balance 9391.939943
# day 62: buy 1 unit at price 798.530029, total balance 8593.409914
# day 67, sell 1 unit at price 809.559998, investment 1.742501 %, total balance 9402.969912,
# day 68, sell 1 unit at price 813.669983, investment 1.895978 %, total balance 10216.639895,
# day 69: buy 1 unit at price 819.239990, total balance 9397.399905
# day 71, sell 1 unit at price 818.979980, investment -0.031738 %, total balance 10216.379885,
# day 72: buy 1 unit at price 824.159973, total balance 9392.219912
# day 73: buy 1 unit at price 828.070007, total balance 8564.149905
# day 74: buy 1 unit at price 831.659973, total balance 7732.489932
# day 76, sell 1 unit at price 831.330017, investment 0.869982 %, total balance 8563.819949,
# day 78, sell 1 unit at price 829.280029, investment 0.146126 %, total balance 9393.099978,
# day 79, sell 1 unit at price 823.210022, investment -1.016034 %, total balance 10216.310000,
# day 80: buy 1 unit at price 835.239990, total balance 9381.070010
# day 81: buy 1 unit at price 830.630005, total balance 8550.440005
# day 82: buy 1 unit at price 829.080017, total balance 7721.359988
# day 86: buy 1 unit at price 838.679993, total balance 6882.679995
# day 87, sell 1 unit at price 843.250000, investment 0.959007 %, total balance 7725.929995,
# day 89, sell 1 unit at price 845.619995, investment 1.804653 %, total balance 8571.549990,
# day 90: buy 1 unit at price 847.200012, total balance 7724.349978
# day 91, sell 1 unit at price 848.780029, investment 2.376129 %, total balance 8573.130007,
# day 92: buy 1 unit at price 852.119995, total balance 7721.010012
# day 93, sell 1 unit at price 848.400024, investment 1.158968 %, total balance 8569.410036,
# day 94: buy 1 unit at price 830.460022, total balance 7738.950014
# day 95, sell 1 unit at price 829.590027, investment -2.078610 %, total balance 8568.540041,
# day 97, sell 1 unit at price 814.429993, investment -4.423086 %, total balance 9382.970034,
# day 98, sell 1 unit at price 819.510010, investment -1.318548 %, total balance 10202.480044,
# day 103: buy 1 unit at price 838.549988, total balance 9363.930056
# day 104: buy 1 unit at price 834.570007, total balance 8529.360049
# day 105: buy 1 unit at price 831.409973, total balance 7697.950076
# day 106: buy 1 unit at price 827.880005, total balance 6870.070071
# day 107: buy 1 unit at price 824.669983, total balance 6045.400088
# day 108, sell 1 unit at price 824.729980, investment -1.648084 %, total balance 6870.130068,
# day 109, sell 1 unit at price 823.349976, investment -1.344409 %, total balance 7693.480044,
# day 110, sell 1 unit at price 824.320007, investment -0.852764 %, total balance 8517.800051,
# day 112, sell 1 unit at price 837.169983, investment 1.122141 %, total balance 9354.970034,
# day 115, sell 1 unit at price 841.650024, investment 2.059010 %, total balance 10196.620058,
# day 116: buy 1 unit at price 843.190002, total balance 9353.430056
# day 118: buy 1 unit at price 872.299988, total balance 8481.130068
# day 120: buy 1 unit at price 874.250000, total balance 7606.880068
# day 123, sell 1 unit at price 916.440002, investment 8.687247 %, total balance 8523.320070,
# day 124, sell 1 unit at price 927.039978, investment 6.275363 %, total balance 9450.360048,
# day 129: buy 1 unit at price 928.780029, total balance 8521.580019
# day 136: buy 1 unit at price 934.010010, total balance 7587.570009
# day 138, sell 1 unit at price 948.820007, investment 8.529598 %, total balance 8536.390016,
# day 139: buy 1 unit at price 954.960022, total balance 7581.429994
# day 140: buy 1 unit at price 969.539978, total balance 6611.890016
# day 141, sell 1 unit at price 971.469971, investment 4.596346 %, total balance 7583.359987,
# day 142, sell 1 unit at price 975.880005, investment 4.482821 %, total balance 8559.239992,
# day 144, sell 1 unit at price 966.950012, investment 1.255549 %, total balance 9526.190004,
# day 145, sell 1 unit at price 975.599976, investment 0.625038 %, total balance 10501.789980,
# day 146: buy 1 unit at price 983.679993, total balance 9518.109987
# day 147, sell 1 unit at price 976.570007, investment -0.722795 %, total balance 10494.679994,
# day 155: buy 1 unit at price 939.780029, total balance 9554.899965
# day 160: buy 1 unit at price 965.590027, total balance 8589.309938
# day 161: buy 1 unit at price 952.270020, total balance 7637.039918
# day 162, sell 1 unit at price 927.330017, investment -1.324779 %, total balance 8564.369935,
# day 164: buy 1 unit at price 917.789978, total balance 7646.579957
# day 165, sell 1 unit at price 908.729980, investment -5.888632 %, total balance 8555.309937,
# day 166, sell 1 unit at price 898.700012, investment -5.625506 %, total balance 9454.009949,
# day 169, sell 1 unit at price 918.590027, investment 0.087171 %, total balance 10372.599976,
# day 171: buy 1 unit at price 930.090027, total balance 9442.509949
# day 172, sell 1 unit at price 943.830017, investment 1.477275 %, total balance 10386.339966,
# day 178: buy 1 unit at price 968.150024, total balance 9418.189942
# day 180, sell 1 unit at price 980.340027, investment 1.259103 %, total balance 10398.529969,
# day 181: buy 1 unit at price 950.700012, total balance 9447.829957
# day 182, sell 1 unit at price 947.799988, investment -0.305041 %, total balance 10395.629945,
# day 188: buy 1 unit at price 923.650024, total balance 9471.979921
# day 192: buy 1 unit at price 922.900024, total balance 8549.079897
# day 193: buy 1 unit at price 907.239990, total balance 7641.839907
# day 194, sell 1 unit at price 914.390015, investment -1.002545 %, total balance 8556.229922,
# day 195, sell 1 unit at price 922.669983, investment -0.024926 %, total balance 9478.899905,
# day 197, sell 1 unit at price 926.960022, investment 2.173629 %, total balance 10405.859927,
# day 198: buy 1 unit at price 910.979980, total balance 9494.879947
# day 199, sell 1 unit at price 910.669983, investment -0.034029 %, total balance 10405.549930,
# day 202: buy 1 unit at price 927.000000, total balance 9478.549930
# day 203: buy 1 unit at price 921.280029, total balance 8557.269901
# day 204: buy 1 unit at price 915.890015, total balance 7641.379886
# day 207, sell 1 unit at price 929.570007, investment 0.277239 %, total balance 8570.949893,
# day 209: buy 1 unit at price 937.340027, total balance 7633.609866
# day 210: buy 1 unit at price 928.450012, total balance 6705.159854
# day 212, sell 1 unit at price 935.950012, investment 1.592348 %, total balance 7641.109866,
# day 214: buy 1 unit at price 929.080017, total balance 6712.029849
# day 219: buy 1 unit at price 915.000000, total balance 5797.029849
# day 220: buy 1 unit at price 921.809998, total balance 4875.219851
# day 221, sell 1 unit at price 931.580017, investment 1.713088 %, total balance 5806.799868,
# day 224, sell 1 unit at price 920.969971, investment -1.746437 %, total balance 6727.769839,
# day 225: buy 1 unit at price 924.859985, total balance 5802.909854
# day 227, sell 1 unit at price 949.500000, investment 2.267218 %, total balance 6752.409854,
# day 230: buy 1 unit at price 957.789978, total balance 5794.619876
# day 231, sell 1 unit at price 951.679993, investment 2.432511 %, total balance 6746.299869,
# day 232, sell 1 unit at price 969.960022, investment 6.006560 %, total balance 7716.259891,
# day 234: buy 1 unit at price 977.000000, total balance 6739.259891
# day 239, sell 1 unit at price 992.000000, investment 7.614368 %, total balance 7731.259891,
# day 250, sell 1 unit at price 1016.640015, investment 9.923668 %, total balance 8747.899906,

# %%
fig = plt.figure(figsize = (15,5))
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.show()
