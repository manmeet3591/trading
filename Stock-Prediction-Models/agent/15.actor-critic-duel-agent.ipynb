# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# Out:
# /home/manmeet/anaconda3/envs/drl/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/manmeet/anaconda3/envs/drl/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/manmeet/anaconda3/envs/drl/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/manmeet/anaconda3/envs/drl/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/manmeet/anaconda3/envs/drl/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/manmeet/anaconda3/envs/drl/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /home/manmeet/anaconda3/envs/drl/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/manmeet/anaconda3/envs/drl/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/manmeet/anaconda3/envs/drl/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/manmeet/anaconda3/envs/drl/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/manmeet/anaconda3/envs/drl/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/manmeet/anaconda3/envs/drl/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
df = pd.read_csv('../dataset/GOOG-year.csv')
df = pd.read_csv('../dataset/BTC-USD.csv')
df.head()
# Out:
#          Date          Open          High           Low         Close  \
# 0  2020-07-25   9539.485352   9704.556641   9530.211914   9677.113281
# 1  2020-07-26   9680.234375  10023.807617   9652.847656   9905.166992
# 2  2020-07-27   9905.217773  11298.221680   9903.969727  10990.873047
# 3  2020-07-28  11017.463867  11204.327148  10632.631836  10912.823242
# 4  2020-07-29  10912.953125  11304.397461  10856.141602  11100.467773
#
#       Adj Close        Volume
# 0   9677.113281  1.661007e+10
# 1   9905.166992  2.050800e+10
# 2  10990.873047  3.535975e+10
# 3  10912.823242  2.876655e+10
# 4  11100.467773  2.461725e+10

# %%
from collections import deque
import random

class Actor:
    def __init__(self, name, input_size, output_size, size_layer):
        with tf.variable_scope(name):
            self.X = tf.placeholder(tf.float32, (None, input_size))
            feed_actor = tf.layers.dense(self.X, size_layer, activation = tf.nn.relu)
            tensor_action, tensor_validation = tf.split(feed_actor,2,1)
            feed_action = tf.layers.dense(tensor_action, output_size)
            feed_validation = tf.layers.dense(tensor_validation, 1)
            self.logits = feed_validation + tf.subtract(feed_action,
                                                        tf.reduce_mean(feed_action,axis=1,keep_dims=True))

class Critic:
    def __init__(self, name, input_size, output_size, size_layer, learning_rate):
        with tf.variable_scope(name):
            self.X = tf.placeholder(tf.float32, (None, input_size))
            self.Y = tf.placeholder(tf.float32, (None, output_size))
            self.REWARD = tf.placeholder(tf.float32, (None, 1))
            feed_critic = tf.layers.dense(self.X, size_layer, activation = tf.nn.relu)
            tensor_action, tensor_validation = tf.split(feed_critic,2,1)
            feed_action = tf.layers.dense(tensor_action, output_size)
            feed_validation = tf.layers.dense(tensor_validation, 1)
            feed_critic = feed_validation + tf.subtract(feed_action,tf.reduce_mean(feed_action,axis=1,keep_dims=True))
            feed_critic = tf.nn.relu(feed_critic) + self.Y
            feed_critic = tf.layers.dense(feed_critic, size_layer//2, activation = tf.nn.relu)
            self.logits = tf.layers.dense(feed_critic, 1)
            self.cost = tf.reduce_mean(tf.square(self.REWARD - self.logits))
            self.optimizer = tf.train.AdamOptimizer(learning_rate).minimize(self.cost)
            
class Agent:

    LEARNING_RATE = 0.001
    BATCH_SIZE = 32
    LAYER_SIZE = 256
    OUTPUT_SIZE = 3
    EPSILON = 0.5
    DECAY_RATE = 0.005
    MIN_EPSILON = 0.1
    GAMMA = 0.99
    MEMORIES = deque()
    MEMORY_SIZE = 300
    COPY = 1000
    T_COPY = 0

    def __init__(self, state_size, window_size, trend, skip):
        self.state_size = state_size
        self.window_size = window_size
        self.half_window = window_size // 2
        self.trend = trend
        self.skip = skip
        tf.reset_default_graph()
        self.actor = Actor('actor-original', self.state_size, self.OUTPUT_SIZE, self.LAYER_SIZE)
        self.actor_target = Actor('actor-target', self.state_size, self.OUTPUT_SIZE, self.LAYER_SIZE)
        self.critic = Critic('critic-original', self.state_size, self.OUTPUT_SIZE, self.LAYER_SIZE, self.LEARNING_RATE)
        self.critic_target = Critic('critic-target', self.state_size, self.OUTPUT_SIZE, 
                                    self.LAYER_SIZE, self.LEARNING_RATE)
        self.grad_critic = tf.gradients(self.critic.logits, self.critic.Y)
        self.actor_critic_grad = tf.placeholder(tf.float32, [None, self.OUTPUT_SIZE])
        weights_actor = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, scope='actor')
        self.grad_actor = tf.gradients(self.actor.logits, weights_actor, -self.actor_critic_grad)
        grads = zip(self.grad_actor, weights_actor)
        self.optimizer = tf.train.AdamOptimizer(self.LEARNING_RATE).apply_gradients(grads)
        self.sess = tf.InteractiveSession()
        self.sess.run(tf.global_variables_initializer())
    
    def _assign(self, from_name, to_name):
        from_w = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, scope=from_name)
        to_w = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, scope=to_name)
        for i in range(len(from_w)):
            assign_op = to_w[i].assign(from_w[i])
            self.sess.run(assign_op)
            
    def _memorize(self, state, action, reward, new_state, dead):
        self.MEMORIES.append((state, action, reward, new_state, dead))
        if len(self.MEMORIES) > self.MEMORY_SIZE:
            self.MEMORIES.popleft()
            
    def _select_action(self, state):
        if np.random.rand() < self.EPSILON:
            action = np.random.randint(self.OUTPUT_SIZE)
        else:
            prediction = self.sess.run(self.actor.logits, feed_dict={self.actor.X:[state]})[0]
            action = np.argmax(prediction)
        return action
    
    def _construct_memories_and_train(self, replay):
        states = np.array([a[0] for a in replay])
        new_states = np.array([a[3] for a in replay])
        Q = self.sess.run(self.actor.logits, feed_dict={self.actor.X: states})
        Q_target = self.sess.run(self.actor_target.logits, feed_dict={self.actor_target.X: states})
        grads = self.sess.run(self.grad_critic, feed_dict={self.critic.X:states, self.critic.Y:Q})[0]
        self.sess.run(self.optimizer, feed_dict={self.actor.X:states, self.actor_critic_grad:grads})
        
        rewards = np.array([a[2] for a in replay]).reshape((-1, 1))
        rewards_target = self.sess.run(self.critic_target.logits, 
                                       feed_dict={self.critic_target.X:new_states,self.critic_target.Y:Q_target})
        for i in range(len(replay)):
            if not replay[0][-1]:
                rewards[i] += self.GAMMA * rewards_target[i]
        cost, _ = self.sess.run([self.critic.cost, self.critic.optimizer], 
                                feed_dict={self.critic.X:states, self.critic.Y:Q, self.critic.REWARD:rewards})
        return cost
    
    def get_state(self, t):
        window_size = self.window_size + 1
        d = t - window_size + 1
        block = self.trend[d : t + 1] if d >= 0 else -d * [self.trend[0]] + self.trend[0 : t + 1]
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])
        return np.array(res)
    
    def buy(self, initial_money):
        starting_money = initial_money
        states_sell = []
        states_buy = []
        inventory = []
        state = self.get_state(0)
        for t in range(0, len(self.trend) - 1, self.skip):
            action = self._select_action(state)
            next_state = self.get_state(t + 1)
            
            if action == 1 and initial_money >= self.trend[t]:
                inventory.append(self.trend[t])
                initial_money -= self.trend[t]
                states_buy.append(t)
                print('day %d: buy 1 unit at price %f, total balance %f'% (t, self.trend[t], initial_money))
            
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                initial_money += self.trend[t]
                states_sell.append(t)
                try:
                    invest = ((close[t] - bought_price) / bought_price) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell 1 unit at price %f, investment %f %%, total balance %f,'
                    % (t, close[t], invest, initial_money)
                )
            
            state = next_state
        invest = ((initial_money - starting_money) / starting_money) * 100
        total_gains = initial_money - starting_money
        return states_buy, states_sell, total_gains, invest
    
    def train(self, iterations, checkpoint, initial_money):
        for i in range(iterations):
            total_profit = 0
            inventory = []
            state = self.get_state(0)
            starting_money = initial_money
            for t in range(0, len(self.trend) - 1, self.skip):
                if (self.T_COPY + 1) % self.COPY == 0:
                    self._assign('actor-original', 'actor-target')
                    self._assign('critic-original', 'critic-target')
                
                action = self._select_action(state)
                next_state = self.get_state(t + 1)
                
                if action == 1 and starting_money >= self.trend[t]:
                    inventory.append(self.trend[t])
                    starting_money -= self.trend[t]
                
                elif action == 2 and len(inventory) > 0:
                    bought_price = inventory.pop(0)
                    total_profit += self.trend[t] - bought_price
                    starting_money += self.trend[t]
                    
                invest = ((starting_money - initial_money) / initial_money)
                
                self._memorize(state, action, invest, next_state, starting_money < initial_money)
                batch_size = min(len(self.MEMORIES), self.BATCH_SIZE)
                state = next_state
                replay = random.sample(self.MEMORIES, batch_size)
                cost = self._construct_memories_and_train(replay)
                self.T_COPY += 1
                self.EPSILON = self.MIN_EPSILON + (1.0 - self.MIN_EPSILON) * np.exp(-self.DECAY_RATE * i)
            if (i+1) % checkpoint == 0:
                print('epoch: %d, total rewards: %f.3, cost: %f, total money: %f'%(i + 1, total_profit, cost,
                                                                                  starting_money))

# %%
close = df.Close.values.tolist()
initial_money = 1000000
window_size = 30
skip = 1
batch_size = 32
agent = Agent(state_size = window_size, 
              window_size = window_size, 
              trend = close, 
              skip = skip)
agent.train(iterations = 200, checkpoint = 10, initial_money = initial_money)
# Out:
# WARNING:tensorflow:From <ipython-input-3-a50a3d0b4e36>:8: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dense instead.
# WARNING:tensorflow:From /home/manmeet/anaconda3/envs/drl/lib/python3.6/site-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# epoch: 10, total rewards: -141154.411138.3, cost: nan, total money: 275455.299797
# epoch: 20, total rewards: nan.3, cost: nan, total money: nan
# epoch: 30, total rewards: nan.3, cost: nan, total money: nan
# epoch: 40, total rewards: nan.3, cost: nan, total money: nan
# epoch: 50, total rewards: -7117.896484.3, cost: nan, total money: 657788.964843
# epoch: 60, total rewards: nan.3, cost: nan, total money: nan
# epoch: 70, total rewards: nan.3, cost: nan, total money: nan
# epoch: 80, total rewards: 66269.194334.3, cost: nan, total money: 905006.690428
# epoch: 90, total rewards: 31838.272461.3, cost: nan, total money: 999525.166992
# epoch: 100, total rewards: nan.3, cost: nan, total money: nan
# epoch: 110, total rewards: nan.3, cost: nan, total money: nan
# epoch: 120, total rewards: nan.3, cost: nan, total money: nan
# epoch: 130, total rewards: nan.3, cost: nan, total money: nan
# epoch: 140, total rewards: 222493.825194.3, cost: nan, total money: 127124.932615
# epoch: 150, total rewards: nan.3, cost: nan, total money: nan
# epoch: 160, total rewards: nan.3, cost: nan, total money: nan
# epoch: 170, total rewards: nan.3, cost: nan, total money: nan
# epoch: 180, total rewards: nan.3, cost: nan, total money: nan
# epoch: 190, total rewards: 104082.123056.3, cost: nan, total money: 1006198.173838
# epoch: 200, total rewards: -84526.276369.3, cost: nan, total money: 688664.829099

# %%
states_buy, states_sell, total_gains, invest = agent.buy(initial_money = initial_money)
# Out:
# day 2: buy 1 unit at price 10990.873047, total balance 989009.126953
# day 5, sell 1 unit at price 11111.213867, investment 1.094916 %, total balance 1000120.340820,
# day 7: buy 1 unit at price 11759.592773, total balance 988360.748047
# day 16: buy 1 unit at price 11878.111328, total balance 976482.636719
# day 25, sell 1 unit at price 11758.283203, investment -0.011136 %, total balance 988240.919922,
# day 32, sell 1 unit at price 11488.363281, investment -3.281229 %, total balance 999729.283203,
# day 35: buy 1 unit at price 11506.865234, total balance 988222.417969
# day 37: buy 1 unit at price 11680.820313, total balance 976541.597656
# day 45: buy 1 unit at price 10131.516602, total balance 966410.081054
# day 48: buy 1 unit at price 10400.915039, total balance 956009.166015
# day 51, sell 1 unit at price 10680.837891, investment -7.178561 %, total balance 966690.003906,
# day 55: buy 1 unit at price 10944.585938, total balance 955745.417968
# day 69: buy 1 unit at price 10585.164063, total balance 945160.253905
# day 77: buy 1 unit at price 11296.361328, total balance 933863.892577
# day 81: buy 1 unit at price 11429.506836, total balance 922434.385741
# day 82, sell 1 unit at price 11495.349609, investment -1.587823 %, total balance 933929.735350,
# day 85: buy 1 unit at price 11483.359375, total balance 922446.375975
# day 92, sell 1 unit at price 13031.173828, investment 28.620170 %, total balance 935477.549803,
# day 96: buy 1 unit at price 13437.882813, total balance 922039.666990
# day 97, sell 1 unit at price 13546.522461, investment 30.243564 %, total balance 935586.189451,
# day 101: buy 1 unit at price 13950.300781, total balance 921635.888670
# day 102: buy 1 unit at price 14133.707031, total balance 907502.181639
# day 104, sell 1 unit at price 15565.880859, investment 42.224484 %, total balance 923068.062498,
# day 107: buy 1 unit at price 15332.315430, total balance 907735.747068
# day 113: buy 1 unit at price 15955.587891, total balance 891780.159177
# day 115, sell 1 unit at price 17645.406250, investment 66.699412 %, total balance 909425.565427,
# day 118: buy 1 unit at price 18621.314453, total balance 890804.250974
# day 119, sell 1 unit at price 18642.232422, investment 65.028648 %, total balance 909446.483396,
# day 120: buy 1 unit at price 18370.001953, total balance 891076.481443
# day 121, sell 1 unit at price 18364.121094, investment 60.672909 %, total balance 909440.602537,
# day 124: buy 1 unit at price 17150.623047, total balance 892289.979490
# day 125: buy 1 unit at price 17108.402344, total balance 875181.577146
# day 126, sell 1 unit at price 17717.414063, investment 54.287726 %, total balance 892898.991209,
# day 130: buy 1 unit at price 19201.091797, total balance 873697.899412
# day 132: buy 1 unit at price 18699.765625, total balance 854998.133787
# day 138, sell 1 unit at price 18264.992188, investment 35.921651 %, total balance 873263.125975,
# day 139, sell 1 unit at price 18058.904297, investment 29.451720 %, total balance 891322.030272,
# day 145, sell 1 unit at price 22805.162109, investment 61.353013 %, total balance 914127.192381,
# day 146: buy 1 unit at price 23137.960938, total balance 890989.231443
# day 157: buy 1 unit at price 27362.437500, total balance 863626.793943
# day 160, sell 1 unit at price 29374.152344, investment 91.583277 %, total balance 893000.946287,
# day 166, sell 1 unit at price 39371.042969, investment 146.753948 %, total balance 932371.989256,
# day 168, sell 1 unit at price 40254.546875, investment 116.174572 %, total balance 972626.536131,
# day 173, sell 1 unit at price 39187.328125, investment 113.322395 %, total balance 1011813.864256,
# day 174, sell 1 unit at price 36825.367188, investment 114.717373 %, total balance 1048639.231444,
# day 176: buy 1 unit at price 35791.277344, total balance 1012847.954100
# day 184, sell 1 unit at price 32366.392578, investment 89.184191 %, total balance 1045214.346678,
# day 187, sell 1 unit at price 31649.605469, investment 64.832322 %, total balance 1076863.952147,
# day 188: buy 1 unit at price 34316.386719, total balance 1042547.565428
# day 190, sell 1 unit at price 33114.359375, investment 77.084355 %, total balance 1075661.924803,
# day 199: buy 1 unit at price 46481.105469, total balance 1029180.819334
# day 200, sell 1 unit at price 44918.183594, investment 94.131988 %, total balance 1074099.002928,
# day 202, sell 1 unit at price 47504.851563, investment 73.613376 %, total balance 1121603.854491,
# day 213, sell 1 unit at price 48824.425781, investment 36.414315 %, total balance 1170428.280272,
# day 214, sell 1 unit at price 49705.332031, investment 44.844306 %, total balance 1220133.612303,
# day 225: buy 1 unit at price 51206.691406, total balance 1168926.920897
# day 226: buy 1 unit at price 52246.523438, total balance 1116680.397459
# day 234, sell 1 unit at price 56804.902344, investment 22.210739 %, total balance 1173485.299803,
# day 235: buy 1 unit at price 58870.894531, total balance 1114614.405272
# day 236, sell 1 unit at price 57858.921875, investment 12.990940 %, total balance 1172473.327147,
# day 241: buy 1 unit at price 54738.945313, total balance 1117734.381834
# day 243, sell 1 unit at price 51704.160156, investment -1.038085 %, total balance 1169438.541990,
# day 244, sell 1 unit at price 55137.312500, investment -6.341983 %, total balance 1224575.854490,
# day 245: buy 1 unit at price 55973.511719, total balance 1168602.342771
# day 247: buy 1 unit at price 57750.199219, total balance 1110852.143552
# day 253: buy 1 unit at price 58758.554688, total balance 1052093.588864
# day 258, sell 1 unit at price 58245.003906, investment 6.405053 %, total balance 1110338.592770,
# day 259, sell 1 unit at price 59793.234375, investment 6.824161 %, total balance 1170131.827145,
# day 260, sell 1 unit at price 60204.964844, investment 4.250662 %, total balance 1230336.791989,
# day 276: buy 1 unit at price 55033.117188, total balance 1175303.674801
# day 278: buy 1 unit at price 53555.109375, total balance 1121748.565426
# day 279: buy 1 unit at price 57750.175781, total balance 1063998.389645
# day 280: buy 1 unit at price 57828.050781, total balance 1006170.338864
# day 281: buy 1 unit at price 56631.078125, total balance 949539.260739
# day 282, sell 1 unit at price 57200.292969, investment -2.651974 %, total balance 1006739.553708,
# day 284, sell 1 unit at price 57424.007813, investment 4.344458 %, total balance 1064163.561521,
# day 286, sell 1 unit at price 57356.402344, investment 7.097909 %, total balance 1121519.963865,
# day 287, sell 1 unit at price 58803.777344, investment 1.824413 %, total balance 1180323.741209,
# day 288, sell 1 unit at price 58232.316406, investment 0.699082 %, total balance 1238556.057615,
# day 289: buy 1 unit at price 55859.796875, total balance 1182696.260740
# day 294, sell 1 unit at price 46760.187500, investment -17.430165 %, total balance 1229456.448240,
# day 297: buy 1 unit at price 42909.402344, total balance 1186547.045896
# day 301: buy 1 unit at price 37536.632813, total balance 1149010.413083
# day 303, sell 1 unit at price 38705.980469, investment -30.708698 %, total balance 1187716.393552,
# day 309, sell 1 unit at price 35678.128906, investment -16.852422 %, total balance 1223394.522458,
# day 310, sell 1 unit at price 37332.855469, investment -0.542876 %, total balance 1260727.377927,
# day 312: buy 1 unit at price 37575.179688, total balance 1223152.198239
# day 319: buy 1 unit at price 37345.121094, total balance 1185807.077145
# day 325, sell 1 unit at price 40406.269531, investment 7.534468 %, total balance 1226213.346676,
# day 329, sell 1 unit at price 35615.871094, investment -4.630458 %, total balance 1261829.217770,
# day 335: buy 1 unit at price 31637.779297, total balance 1230191.438473
# day 340, sell 1 unit at price 35040.835938, investment 10.756307 %, total balance 1265232.274411,
# day 346: buy 1 unit at price 34235.195313, total balance 1230997.079098
# day 347, sell 1 unit at price 33855.328125, investment -1.109581 %, total balance 1264852.407223,
# day 351: buy 1 unit at price 34240.187500, total balance 1230612.219723
# day 358, sell 1 unit at price 31796.810547, investment -7.135992 %, total balance 1262409.030270,

# %%
fig = plt.figure(figsize = (15,5))
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.show()
