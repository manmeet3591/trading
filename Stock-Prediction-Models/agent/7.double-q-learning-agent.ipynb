# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# Out:
# /home/manmeet/anaconda3/envs/drl/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/manmeet/anaconda3/envs/drl/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/manmeet/anaconda3/envs/drl/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/manmeet/anaconda3/envs/drl/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/manmeet/anaconda3/envs/drl/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/manmeet/anaconda3/envs/drl/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /home/manmeet/anaconda3/envs/drl/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/manmeet/anaconda3/envs/drl/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/manmeet/anaconda3/envs/drl/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/manmeet/anaconda3/envs/drl/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/manmeet/anaconda3/envs/drl/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/manmeet/anaconda3/envs/drl/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
df = pd.read_csv('../dataset/GOOG-year.csv')
df = pd.read_csv('../dataset/BTC-USD.csv')
df.head()
# Out:
#          Date          Open          High           Low         Close  \
# 0  2020-07-25   9539.485352   9704.556641   9530.211914   9677.113281
# 1  2020-07-26   9680.234375  10023.807617   9652.847656   9905.166992
# 2  2020-07-27   9905.217773  11298.221680   9903.969727  10990.873047
# 3  2020-07-28  11017.463867  11204.327148  10632.631836  10912.823242
# 4  2020-07-29  10912.953125  11304.397461  10856.141602  11100.467773
#
#       Adj Close        Volume
# 0   9677.113281  1.661007e+10
# 1   9905.166992  2.050800e+10
# 2  10990.873047  3.535975e+10
# 3  10912.823242  2.876655e+10
# 4  11100.467773  2.461725e+10

# %%
from collections import deque
import random

class Model:
    def __init__(self, input_size, output_size, layer_size, learning_rate):
        self.X = tf.placeholder(tf.float32, (None, input_size))
        self.Y = tf.placeholder(tf.float32, (None, output_size))
        feed_forward = tf.layers.dense(self.X, layer_size, activation = tf.nn.relu)
        self.logits = tf.layers.dense(feed_forward, output_size)
        self.cost = tf.reduce_sum(tf.square(self.Y - self.logits))
        self.optimizer = tf.train.AdamOptimizer(learning_rate = learning_rate).minimize(self.cost)
        
class Agent:

    LEARNING_RATE = 0.003
    BATCH_SIZE = 32
    LAYER_SIZE = 500
    OUTPUT_SIZE = 3
    EPSILON = 0.5
    DECAY_RATE = 0.005
    MIN_EPSILON = 0.1
    GAMMA = 0.99
    MEMORIES = deque()
    COPY = 1000
    T_COPY = 0
    MEMORY_SIZE = 300
    
    def __init__(self, state_size, window_size, trend, skip):
        self.state_size = state_size
        self.window_size = window_size
        self.half_window = window_size // 2
        self.trend = trend
        self.skip = skip
        tf.reset_default_graph()
        self.model = Model(self.state_size, self.OUTPUT_SIZE, self.LAYER_SIZE, self.LEARNING_RATE)
        self.model_negative = Model(self.state_size, self.OUTPUT_SIZE, self.LAYER_SIZE, self.LEARNING_RATE)
        self.sess = tf.InteractiveSession()
        self.sess.run(tf.global_variables_initializer())
        self.trainable = tf.trainable_variables()
    
    def _assign(self):
        for i in range(len(self.trainable)//2):
            assign_op = self.trainable[i+len(self.trainable)//2].assign(self.trainable[i])
            self.sess.run(assign_op)

    def _memorize(self, state, action, reward, new_state, done):
        self.MEMORIES.append((state, action, reward, new_state, done))
        if len(self.MEMORIES) > self.MEMORY_SIZE:
            self.MEMORIES.popleft()

    def _select_action(self, state):
        if np.random.rand() < self.EPSILON:
            action = np.random.randint(self.OUTPUT_SIZE)
        else:
            action = self.get_predicted_action([state])
        return action

    def _construct_memories(self, replay):
        states = np.array([a[0] for a in replay])
        new_states = np.array([a[3] for a in replay])
        Q = self.predict(states)
        Q_new = self.predict(new_states)
        Q_new_negative = self.sess.run(self.model_negative.logits, feed_dict={self.model_negative.X:new_states})
        replay_size = len(replay)
        X = np.empty((replay_size, self.state_size))
        Y = np.empty((replay_size, self.OUTPUT_SIZE))
        for i in range(replay_size):
            state_r, action_r, reward_r, new_state_r, done_r = replay[i]
            target = Q[i]
            target[action_r] = reward_r
            if not done_r:
                target[action_r] += self.GAMMA * Q_new_negative[i, np.argmax(Q_new[i])]
            X[i] = state_r
            Y[i] = target
        return X, Y

    def predict(self, inputs):
        return self.sess.run(self.model.logits, feed_dict={self.model.X:inputs})
    
    def get_predicted_action(self, sequence):
        prediction = self.predict(np.array(sequence))[0]
        return np.argmax(prediction)
    
    def get_state(self, t):
        window_size = self.window_size + 1
        d = t - window_size + 1
        block = self.trend[d : t + 1] if d >= 0 else -d * [self.trend[0]] + self.trend[0 : t + 1]
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])
        return np.array(res)
    
    def buy(self, initial_money):
        starting_money = initial_money
        states_sell = []
        states_buy = []
        inventory = []
        state = self.get_state(0)
        for t in range(0, len(self.trend) - 1, self.skip):
            action = self._select_action(state)
            next_state = self.get_state(t + 1)
            
            if action == 1 and initial_money >= self.trend[t]:
                inventory.append(self.trend[t])
                initial_money -= self.trend[t]
                states_buy.append(t)
                print('day %d: buy 1 unit at price %f, total balance %f'% (t, self.trend[t], initial_money))
            
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                initial_money += self.trend[t]
                states_sell.append(t)
                try:
                    invest = ((close[t] - bought_price) / bought_price) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell 1 unit at price %f, investment %f %%, total balance %f,'
                    % (t, close[t], invest, initial_money)
                )
            
            state = next_state
        invest = ((initial_money - starting_money) / starting_money) * 100
        total_gains = initial_money - starting_money
        return states_buy, states_sell, total_gains, invest
            
    
    def train(self, iterations, checkpoint, initial_money):
        for i in range(iterations):
            total_profit = 0
            inventory = []
            state = self.get_state(0)
            starting_money = initial_money
            for t in range(0, len(self.trend) - 1, self.skip):
                if (self.T_COPY + 1) % self.COPY == 0:
                    self._assign()
                
                action = self._select_action(state)
                next_state = self.get_state(t + 1)
                
                if action == 1 and starting_money >= self.trend[t]:
                    inventory.append(self.trend[t])
                    starting_money -= self.trend[t]
                
                elif action == 2 and len(inventory) > 0:
                    bought_price = inventory.pop(0)
                    total_profit += self.trend[t] - bought_price
                    starting_money += self.trend[t]
                    
                invest = ((starting_money - initial_money) / initial_money)
                
                self._memorize(state, action, invest, next_state, starting_money < initial_money)
                batch_size = min(len(self.MEMORIES), self.BATCH_SIZE)
                replay = random.sample(self.MEMORIES, batch_size)
                state = next_state
                X, Y = self._construct_memories(replay)
                
                cost, _ = self.sess.run([self.model.cost, self.model.optimizer], 
                                        feed_dict={self.model.X: X, self.model.Y:Y})
                self.T_COPY += 1
                self.EPSILON = self.MIN_EPSILON + (1.0 - self.MIN_EPSILON) * np.exp(-self.DECAY_RATE * i)
            if (i+1) % checkpoint == 0:
                print('epoch: %d, total rewards: %f.3, cost: %f, total money: %f'%(i + 1, total_profit, cost,
                                                                                  starting_money))

# %%
close = df.Close.values.tolist()
initial_money = 1000000
window_size = 30
skip = 1
batch_size = 32
agent = Agent(state_size = window_size, 
              window_size = window_size, 
              trend = close, 
              skip = skip)
agent.train(iterations = 200, checkpoint = 10, initial_money = initial_money)
# Out:
# WARNING:tensorflow:From <ipython-input-3-b061ca58b275>:8: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dense instead.
# WARNING:tensorflow:From /home/manmeet/anaconda3/envs/drl/lib/python3.6/site-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# epoch: 10, total rewards: nan.3, cost: nan, total money: nan
# epoch: 20, total rewards: 251483.695310.3, cost: nan, total money: 908080.289059
# epoch: 30, total rewards: nan.3, cost: nan, total money: nan
# epoch: 40, total rewards: 203443.058594.3, cost: nan, total money: 1007688.236329
# epoch: 50, total rewards: nan.3, cost: nan, total money: nan
# epoch: 60, total rewards: -99216.711916.3, cost: nan, total money: 619608.834959
# epoch: 70, total rewards: 275752.133789.3, cost: nan, total money: 1215126.954102
# epoch: 80, total rewards: 184345.622075.3, cost: nan, total money: 116403.182621
# epoch: 90, total rewards: 78973.835938.3, cost: nan, total money: 1078973.835938
# epoch: 100, total rewards: nan.3, cost: nan, total money: nan
# epoch: 110, total rewards: 154528.575195.3, cost: nan, total money: 1053777.208007
# epoch: 120, total rewards: nan.3, cost: nan, total money: nan
# epoch: 130, total rewards: nan.3, cost: nan, total money: nan
# epoch: 140, total rewards: nan.3, cost: nan, total money: nan
# epoch: 150, total rewards: 63386.841797.3, cost: nan, total money: 967349.458984
# epoch: 160, total rewards: nan.3, cost: nan, total money: nan
# epoch: 170, total rewards: 4738.486329.3, cost: nan, total money: 842502.263673
# epoch: 180, total rewards: nan.3, cost: nan, total money: nan
# epoch: 190, total rewards: 111254.601568.3, cost: nan, total money: 1013212.703130
# epoch: 200, total rewards: 91059.388671.3, cost: nan, total money: 1057204.060546

# %%
states_buy, states_sell, total_gains, invest = agent.buy(initial_money = initial_money)
# Out:
# day 6: buy 1 unit at price 11323.466797, total balance 988676.533203
# day 17: buy 1 unit at price 11410.525391, total balance 977266.007812
# day 32, sell 1 unit at price 11488.363281, investment 1.456237 %, total balance 988754.371093,
# day 42, sell 1 unit at price 10169.567383, investment -10.875555 %, total balance 998923.938476,
# day 48: buy 1 unit at price 10400.915039, total balance 988523.023437
# day 50, sell 1 unit at price 10323.755859, investment -0.741850 %, total balance 998846.779296,
# day 67: buy 1 unit at price 10787.618164, total balance 988059.161132
# day 70: buy 1 unit at price 10565.493164, total balance 977493.667968
# day 71, sell 1 unit at price 10684.428711, investment -0.956555 %, total balance 988178.096679,
# day 75: buy 1 unit at price 10923.627930, total balance 977254.468749
# day 78: buy 1 unit at price 11384.181641, total balance 965870.287108
# day 81, sell 1 unit at price 11429.506836, investment 8.177694 %, total balance 977299.793944,
# day 91, sell 1 unit at price 13108.062500, investment 19.997336 %, total balance 990407.856444,
# day 92: buy 1 unit at price 13031.173828, total balance 977376.682616
# day 95, sell 1 unit at price 13271.285156, investment 16.576541 %, total balance 990647.967772,
# day 96, sell 1 unit at price 13437.882813, investment 3.121046 %, total balance 1004085.850585,
# day 98: buy 1 unit at price 13780.995117, total balance 990304.855468
# day 102, sell 1 unit at price 14133.707031, investment 2.559408 %, total balance 1004438.562499,
# day 104: buy 1 unit at price 15565.880859, total balance 988872.681640
# day 110: buy 1 unit at price 16276.343750, total balance 972596.337890
# day 121, sell 1 unit at price 18364.121094, investment 17.976755 %, total balance 990960.458984,
# day 128: buy 1 unit at price 19625.835938, total balance 971334.623046
# day 129: buy 1 unit at price 18802.998047, total balance 952531.624999
# day 130: buy 1 unit at price 19201.091797, total balance 933330.533202
# day 136: buy 1 unit at price 18321.144531, total balance 915009.388671
# day 146, sell 1 unit at price 23137.960938, investment 42.156994 %, total balance 938147.349609,
# day 147, sell 1 unit at price 23869.832031, investment 21.624537 %, total balance 962017.181640,
# day 148: buy 1 unit at price 23477.294922, total balance 938539.886718
# day 149: buy 1 unit at price 22803.082031, total balance 915736.804687
# day 152, sell 1 unit at price 23735.949219, investment 26.234918 %, total balance 939472.753906,
# day 158, sell 1 unit at price 28840.953125, investment 50.204756 %, total balance 968313.707031,
# day 159, sell 1 unit at price 29001.720703, investment 58.296446 %, total balance 997315.427734,
# day 164: buy 1 unit at price 33992.429688, total balance 963322.998046
# day 166: buy 1 unit at price 39371.042969, total balance 923951.955077
# day 179, sell 1 unit at price 35547.750000, investment 51.413313 %, total balance 959499.705077,
# day 181, sell 1 unit at price 33005.761719, investment 44.742547 %, total balance 992505.466796,
# day 183: buy 1 unit at price 32289.378906, total balance 960216.087890
# day 190, sell 1 unit at price 33114.359375, investment -2.583135 %, total balance 993330.447265,
# day 191, sell 1 unit at price 33537.175781, investment -14.817660 %, total balance 1026867.623046,
# day 196: buy 1 unit at price 39266.011719, total balance 987601.611327
# day 199, sell 1 unit at price 46481.105469, investment 43.951686 %, total balance 1034082.716796,
# day 200, sell 1 unit at price 44918.183594, investment 14.394566 %, total balance 1079000.900390,
# day 204: buy 1 unit at price 48717.289063, total balance 1030283.611327
# day 205: buy 1 unit at price 47945.058594, total balance 982338.552733
# day 206, sell 1 unit at price 49199.871094, investment 0.990577 %, total balance 1031538.423827,
# day 212: buy 1 unit at price 54207.320313, total balance 977331.103514
# day 213, sell 1 unit at price 48824.425781, investment 1.834114 %, total balance 1026155.529295,
# day 214, sell 1 unit at price 49705.332031, investment -8.305130 %, total balance 1075860.861326,
# day 215: buy 1 unit at price 47093.851563, total balance 1028767.009763
# day 217: buy 1 unit at price 46188.453125, total balance 982578.556638
# day 218, sell 1 unit at price 45137.769531, investment -4.153583 %, total balance 1027716.326169,
# day 222, sell 1 unit at price 48561.167969, investment 5.137030 %, total balance 1076277.494138,
# day 226: buy 1 unit at price 52246.523438, total balance 1024030.970700
# day 229, sell 1 unit at price 57805.121094, investment 10.639172 %, total balance 1081836.091794,
# day 230: buy 1 unit at price 57332.089844, total balance 1024504.001950
# day 236: buy 1 unit at price 57858.921875, total balance 966645.080075
# day 237, sell 1 unit at price 58346.652344, investment 1.769624 %, total balance 1024991.732419,
# day 239: buy 1 unit at price 57523.421875, total balance 967468.310544
# day 245: buy 1 unit at price 55973.511719, total balance 911494.798825
# day 249, sell 1 unit at price 58918.832031, investment 1.831887 %, total balance 970413.630856,
# day 250, sell 1 unit at price 59095.808594, investment 2.733472 %, total balance 1029509.439450,
# day 254: buy 1 unit at price 59057.878906, total balance 970451.560544
# day 256: buy 1 unit at price 56048.937500, total balance 914402.623044
# day 259: buy 1 unit at price 59793.234375, total balance 854609.388669
# day 262, sell 1 unit at price 63503.457031, investment 13.452694 %, total balance 918112.845700,
# day 263: buy 1 unit at price 63109.695313, total balance 855003.150387
# day 268: buy 1 unit at price 55724.265625, total balance 799278.884762
# day 269, sell 1 unit at price 56473.031250, investment -4.376804 %, total balance 855751.916012,
# day 270, sell 1 unit at price 53906.089844, investment -3.823173 %, total balance 909658.005856,
# day 271: buy 1 unit at price 51762.273438, total balance 857895.732418
# day 272, sell 1 unit at price 51093.652344, investment -14.549442 %, total balance 908989.384762,
# day 273: buy 1 unit at price 50050.867188, total balance 858938.517574
# day 274: buy 1 unit at price 49004.253906, total balance 809934.263668
# day 276, sell 1 unit at price 55033.117188, investment -12.797682 %, total balance 864967.380856,
# day 277, sell 1 unit at price 54824.703125, investment -1.614310 %, total balance 919792.083981,
# day 281: buy 1 unit at price 56631.078125, total balance 863161.005856
# day 284: buy 1 unit at price 57424.007813, total balance 805736.998043
# day 292: buy 1 unit at price 49716.191406, total balance 756020.806637
# day 293, sell 1 unit at price 49880.535156, investment -3.635347 %, total balance 805901.341793,
# day 295: buy 1 unit at price 46456.058594, total balance 759445.283199
# day 301: buy 1 unit at price 37536.632813, total balance 721908.650386
# day 302, sell 1 unit at price 34770.582031, investment -30.529511 %, total balance 756679.232417,
# day 303: buy 1 unit at price 38705.980469, total balance 717973.251948
# day 304: buy 1 unit at price 38402.222656, total balance 679571.029292
# day 305: buy 1 unit at price 39294.199219, total balance 640276.830073
# day 310, sell 1 unit at price 37332.855469, investment -23.817113 %, total balance 677609.685542,
# day 325, sell 1 unit at price 40406.269531, investment -28.650008 %, total balance 718015.955073,
# day 328, sell 1 unit at price 35787.246094, investment -37.678947 %, total balance 753803.201167,
# day 330, sell 1 unit at price 35698.296875, investment -28.195833 %, total balance 789501.498042,
# day 336, sell 1 unit at price 32186.277344, investment -30.716728 %, total balance 821687.775386,
# day 337: buy 1 unit at price 34649.644531, total balance 787038.130855
# day 340, sell 1 unit at price 35040.835938, investment -6.648963 %, total balance 822078.966793,
# day 343, sell 1 unit at price 34668.546875, investment -10.431033 %, total balance 856747.513668,
# day 349, sell 1 unit at price 33798.011719, investment -11.989439 %, total balance 890545.525387,
# day 355: buy 1 unit at price 31780.730469, total balance 858764.794918
# day 358: buy 1 unit at price 31796.810547, total balance 826967.984371
# day 361: buy 1 unit at price 32110.693359, total balance 794857.291012

# %%
fig = plt.figure(figsize = (15,5))
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.show()
