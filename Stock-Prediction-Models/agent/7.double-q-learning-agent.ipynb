# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# Out:
# /home/manmeet/anaconda3/envs/drl/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/manmeet/anaconda3/envs/drl/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/manmeet/anaconda3/envs/drl/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/manmeet/anaconda3/envs/drl/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/manmeet/anaconda3/envs/drl/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/manmeet/anaconda3/envs/drl/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /home/manmeet/anaconda3/envs/drl/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/manmeet/anaconda3/envs/drl/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/manmeet/anaconda3/envs/drl/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/manmeet/anaconda3/envs/drl/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/manmeet/anaconda3/envs/drl/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/manmeet/anaconda3/envs/drl/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
df = pd.read_csv('../dataset/GOOG-year.csv')
df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2016-11-02  778.200012  781.650024  763.450012  768.700012  768.700012
# 1  2016-11-03  767.250000  769.950012  759.030029  762.130005  762.130005
# 2  2016-11-04  750.659973  770.359985  750.560974  762.020020  762.020020
# 3  2016-11-07  774.500000  785.190002  772.549988  782.520020  782.520020
# 4  2016-11-08  783.400024  795.632996  780.190002  790.510010  790.510010
#
#     Volume
# 0  1872400
# 1  1943200
# 2  2134800
# 3  1585100
# 4  1350800

# %%
from collections import deque
import random

class Model:
    def __init__(self, input_size, output_size, layer_size, learning_rate):
        self.X = tf.placeholder(tf.float32, (None, input_size))
        self.Y = tf.placeholder(tf.float32, (None, output_size))
        feed_forward = tf.layers.dense(self.X, layer_size, activation = tf.nn.relu)
        self.logits = tf.layers.dense(feed_forward, output_size)
        self.cost = tf.reduce_sum(tf.square(self.Y - self.logits))
        self.optimizer = tf.train.AdamOptimizer(learning_rate = learning_rate).minimize(self.cost)
        
class Agent:

    LEARNING_RATE = 0.003
    BATCH_SIZE = 32
    LAYER_SIZE = 500
    OUTPUT_SIZE = 3
    EPSILON = 0.5
    DECAY_RATE = 0.005
    MIN_EPSILON = 0.1
    GAMMA = 0.99
    MEMORIES = deque()
    COPY = 1000
    T_COPY = 0
    MEMORY_SIZE = 300
    
    def __init__(self, state_size, window_size, trend, skip):
        self.state_size = state_size
        self.window_size = window_size
        self.half_window = window_size // 2
        self.trend = trend
        self.skip = skip
        tf.reset_default_graph()
        self.model = Model(self.state_size, self.OUTPUT_SIZE, self.LAYER_SIZE, self.LEARNING_RATE)
        self.model_negative = Model(self.state_size, self.OUTPUT_SIZE, self.LAYER_SIZE, self.LEARNING_RATE)
        self.sess = tf.InteractiveSession()
        self.sess.run(tf.global_variables_initializer())
        self.trainable = tf.trainable_variables()
    
    def _assign(self):
        for i in range(len(self.trainable)//2):
            assign_op = self.trainable[i+len(self.trainable)//2].assign(self.trainable[i])
            self.sess.run(assign_op)

    def _memorize(self, state, action, reward, new_state, done):
        self.MEMORIES.append((state, action, reward, new_state, done))
        if len(self.MEMORIES) > self.MEMORY_SIZE:
            self.MEMORIES.popleft()

    def _select_action(self, state):
        if np.random.rand() < self.EPSILON:
            action = np.random.randint(self.OUTPUT_SIZE)
        else:
            action = self.get_predicted_action([state])
        return action

    def _construct_memories(self, replay):
        states = np.array([a[0] for a in replay])
        new_states = np.array([a[3] for a in replay])
        Q = self.predict(states)
        Q_new = self.predict(new_states)
        Q_new_negative = self.sess.run(self.model_negative.logits, feed_dict={self.model_negative.X:new_states})
        replay_size = len(replay)
        X = np.empty((replay_size, self.state_size))
        Y = np.empty((replay_size, self.OUTPUT_SIZE))
        for i in range(replay_size):
            state_r, action_r, reward_r, new_state_r, done_r = replay[i]
            target = Q[i]
            target[action_r] = reward_r
            if not done_r:
                target[action_r] += self.GAMMA * Q_new_negative[i, np.argmax(Q_new[i])]
            X[i] = state_r
            Y[i] = target
        return X, Y

    def predict(self, inputs):
        return self.sess.run(self.model.logits, feed_dict={self.model.X:inputs})
    
    def get_predicted_action(self, sequence):
        prediction = self.predict(np.array(sequence))[0]
        return np.argmax(prediction)
    
    def get_state(self, t):
        window_size = self.window_size + 1
        d = t - window_size + 1
        block = self.trend[d : t + 1] if d >= 0 else -d * [self.trend[0]] + self.trend[0 : t + 1]
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])
        return np.array(res)
    
    def buy(self, initial_money):
        starting_money = initial_money
        states_sell = []
        states_buy = []
        inventory = []
        state = self.get_state(0)
        for t in range(0, len(self.trend) - 1, self.skip):
            action = self._select_action(state)
            next_state = self.get_state(t + 1)
            
            if action == 1 and initial_money >= self.trend[t]:
                inventory.append(self.trend[t])
                initial_money -= self.trend[t]
                states_buy.append(t)
                print('day %d: buy 1 unit at price %f, total balance %f'% (t, self.trend[t], initial_money))
            
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                initial_money += self.trend[t]
                states_sell.append(t)
                try:
                    invest = ((close[t] - bought_price) / bought_price) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell 1 unit at price %f, investment %f %%, total balance %f,'
                    % (t, close[t], invest, initial_money)
                )
            
            state = next_state
        invest = ((initial_money - starting_money) / starting_money) * 100
        total_gains = initial_money - starting_money
        return states_buy, states_sell, total_gains, invest
            
    
    def train(self, iterations, checkpoint, initial_money):
        for i in range(iterations):
            total_profit = 0
            inventory = []
            state = self.get_state(0)
            starting_money = initial_money
            for t in range(0, len(self.trend) - 1, self.skip):
                if (self.T_COPY + 1) % self.COPY == 0:
                    self._assign()
                
                action = self._select_action(state)
                next_state = self.get_state(t + 1)
                
                if action == 1 and starting_money >= self.trend[t]:
                    inventory.append(self.trend[t])
                    starting_money -= self.trend[t]
                
                elif action == 2 and len(inventory) > 0:
                    bought_price = inventory.pop(0)
                    total_profit += self.trend[t] - bought_price
                    starting_money += self.trend[t]
                    
                invest = ((starting_money - initial_money) / initial_money)
                
                self._memorize(state, action, invest, next_state, starting_money < initial_money)
                batch_size = min(len(self.MEMORIES), self.BATCH_SIZE)
                replay = random.sample(self.MEMORIES, batch_size)
                state = next_state
                X, Y = self._construct_memories(replay)
                
                cost, _ = self.sess.run([self.model.cost, self.model.optimizer], 
                                        feed_dict={self.model.X: X, self.model.Y:Y})
                self.T_COPY += 1
                self.EPSILON = self.MIN_EPSILON + (1.0 - self.MIN_EPSILON) * np.exp(-self.DECAY_RATE * i)
            if (i+1) % checkpoint == 0:
                print('epoch: %d, total rewards: %f.3, cost: %f, total money: %f'%(i + 1, total_profit, cost,
                                                                                  starting_money))

# %%
close = df.Close.values.tolist()
initial_money = 10000
window_size = 30
skip = 1
batch_size = 32
agent = Agent(state_size = window_size, 
              window_size = window_size, 
              trend = close, 
              skip = skip)
agent.train(iterations = 200, checkpoint = 10, initial_money = initial_money)
# Out:
# WARNING:tensorflow:From <ipython-input-3-b061ca58b275>:8: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dense instead.
# WARNING:tensorflow:From /home/manmeet/anaconda3/envs/drl/lib/python3.6/site-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# epoch: 10, total rewards: 1154.224975.3, cost: 0.488509, total money: 5292.034973
# epoch: 20, total rewards: 614.465274.3, cost: 0.508612, total money: 7651.465274
# epoch: 30, total rewards: 999.445194.3, cost: 1.471007, total money: 8078.575199
# epoch: 40, total rewards: 1026.844854.3, cost: 1.390136, total money: 4107.784856
# epoch: 50, total rewards: 746.359626.3, cost: 2.640748, total money: 3175.589606
# epoch: 60, total rewards: 346.245056.3, cost: 0.725607, total money: 7388.875060
# epoch: 70, total rewards: 498.795282.3, cost: 0.749687, total money: 8552.905267
# epoch: 80, total rewards: 105.054987.3, cost: 0.199499, total money: 9088.414972
# epoch: 90, total rewards: 1414.129704.3, cost: 1.200494, total money: 171.399663
# epoch: 100, total rewards: 1844.919619.3, cost: 0.648643, total money: 6939.079592
# epoch: 110, total rewards: 1297.504760.3, cost: 0.664734, total money: 8317.474730
# epoch: 120, total rewards: 391.344969.3, cost: 0.623168, total money: 4417.074949
# epoch: 130, total rewards: 707.239800.3, cost: 0.524324, total money: 8717.569817
# epoch: 140, total rewards: -30.624753.3, cost: 0.847936, total money: 5058.005252
# epoch: 150, total rewards: 1366.889590.3, cost: 1.364423, total money: 10347.619570
# epoch: 160, total rewards: 1074.274780.3, cost: 0.686649, total money: 11074.274780
# epoch: 170, total rewards: -1.160038.3, cost: 1.025993, total money: 9998.839962
# epoch: 180, total rewards: 199.970280.3, cost: 0.017151, total money: 9183.330265
# epoch: 190, total rewards: -14.844847.3, cost: 0.008521, total money: 9985.155153
# epoch: 200, total rewards: 94.434995.3, cost: 0.004423, total money: 10094.434995

# %%
states_buy, states_sell, total_gains, invest = agent.buy(initial_money = initial_money)
# Out:
# day 15: buy 1 unit at price 760.989990, total balance 9239.010010
# day 16, sell 1 unit at price 761.679993, investment 0.090672 %, total balance 10000.690003,
# day 18: buy 1 unit at price 770.840027, total balance 9229.849976
# day 19: buy 1 unit at price 758.039978, total balance 8471.809998
# day 20, sell 1 unit at price 747.919983, investment -2.973385 %, total balance 9219.729981,
# day 21, sell 1 unit at price 750.500000, investment -0.994668 %, total balance 9970.229981,
# day 27: buy 1 unit at price 789.270020, total balance 9180.959961
# day 28, sell 1 unit at price 796.099976, investment 0.865351 %, total balance 9977.059937,
# day 37: buy 1 unit at price 791.549988, total balance 9185.509949
# day 38, sell 1 unit at price 785.049988, investment -0.821174 %, total balance 9970.559937,
# day 48: buy 1 unit at price 806.359985, total balance 9164.199952
# day 49, sell 1 unit at price 807.880005, investment 0.188504 %, total balance 9972.079957,
# day 54: buy 1 unit at price 819.309998, total balance 9152.769959
# day 55: buy 1 unit at price 823.869995, total balance 8328.899964
# day 56, sell 1 unit at price 835.669983, investment 1.996800 %, total balance 9164.569947,
# day 57, sell 1 unit at price 832.150024, investment 1.005016 %, total balance 9996.719971,
# day 59: buy 1 unit at price 802.320007, total balance 9194.399964
# day 60: buy 1 unit at price 796.789978, total balance 8397.609986
# day 62, sell 1 unit at price 798.530029, investment -0.472377 %, total balance 9196.140015,
# day 63, sell 1 unit at price 801.489990, investment 0.589868 %, total balance 9997.630005,
# day 66: buy 1 unit at price 808.380005, total balance 9189.250000
# day 67, sell 1 unit at price 809.559998, investment 0.145970 %, total balance 9998.809998,
# day 70: buy 1 unit at price 820.450012, total balance 9178.359986
# day 71: buy 1 unit at price 818.979980, total balance 8359.380006
# day 72, sell 1 unit at price 824.159973, investment 0.452186 %, total balance 9183.539979,
# day 73, sell 1 unit at price 828.070007, investment 1.109921 %, total balance 10011.609986,
# day 78: buy 1 unit at price 829.280029, total balance 9182.329957
# day 79, sell 1 unit at price 823.210022, investment -0.731961 %, total balance 10005.539979,
# day 86: buy 1 unit at price 838.679993, total balance 9166.859986
# day 87: buy 1 unit at price 843.250000, total balance 8323.609986
# day 88, sell 1 unit at price 845.539978, investment 0.817950 %, total balance 9169.149964,
# day 89, sell 1 unit at price 845.619995, investment 0.281055 %, total balance 10014.769959,
# day 92: buy 1 unit at price 852.119995, total balance 9162.649964
# day 93, sell 1 unit at price 848.400024, investment -0.436555 %, total balance 10011.049988,
# day 94: buy 1 unit at price 830.460022, total balance 9180.589966
# day 95, sell 1 unit at price 829.590027, investment -0.104761 %, total balance 10010.179993,
# day 98: buy 1 unit at price 819.510010, total balance 9190.669983
# day 100, sell 1 unit at price 831.409973, investment 1.452083 %, total balance 10022.079956,
# day 107: buy 1 unit at price 824.669983, total balance 9197.409973
# day 108, sell 1 unit at price 824.729980, investment 0.007275 %, total balance 10022.139953,
# day 113: buy 1 unit at price 836.820007, total balance 9185.319946
# day 114: buy 1 unit at price 838.210022, total balance 8347.109924
# day 115, sell 1 unit at price 841.650024, investment 0.577187 %, total balance 9188.759948,
# day 117, sell 1 unit at price 862.760010, investment 2.928859 %, total balance 10051.519958,
# day 127: buy 1 unit at price 934.299988, total balance 9117.219970
# day 128, sell 1 unit at price 932.169983, investment -0.227979 %, total balance 10049.389953,
# day 129: buy 1 unit at price 928.780029, total balance 9120.609924
# day 130, sell 1 unit at price 930.599976, investment 0.195950 %, total balance 10051.209900,
# day 132: buy 1 unit at price 937.080017, total balance 9114.129883
# day 133, sell 1 unit at price 943.000000, investment 0.631748 %, total balance 10057.129883,
# day 148: buy 1 unit at price 980.940002, total balance 9076.189881
# day 149: buy 1 unit at price 983.409973, total balance 8092.779908
# day 150: buy 1 unit at price 949.830017, total balance 7142.949891
# day 151, sell 1 unit at price 942.900024, investment -3.877911 %, total balance 8085.849915,
# day 152, sell 1 unit at price 953.400024, investment -3.051621 %, total balance 9039.249939,
# day 153, sell 1 unit at price 950.760010, investment 0.097912 %, total balance 9990.009949,
# day 156: buy 1 unit at price 957.369995, total balance 9032.639954
# day 157, sell 1 unit at price 950.630005, investment -0.704011 %, total balance 9983.269959,
# day 167: buy 1 unit at price 911.710022, total balance 9071.559937
# day 168, sell 1 unit at price 906.690002, investment -0.550616 %, total balance 9978.249939,
# day 173: buy 1 unit at price 947.159973, total balance 9031.089966
# day 175: buy 1 unit at price 953.419983, total balance 8077.669983
# day 176, sell 1 unit at price 965.400024, investment 1.925762 %, total balance 9043.070007,
# day 177, sell 1 unit at price 970.890015, investment 1.832354 %, total balance 10013.960022,
# day 178: buy 1 unit at price 968.150024, total balance 9045.809998
# day 179, sell 1 unit at price 972.919983, investment 0.492688 %, total balance 10018.729981,
# day 180: buy 1 unit at price 980.340027, total balance 9038.389954
# day 181, sell 1 unit at price 950.700012, investment -3.023442 %, total balance 9989.089966,
# day 187: buy 1 unit at price 930.390015, total balance 9058.699951
# day 188, sell 1 unit at price 923.650024, investment -0.724426 %, total balance 9982.349975,
# day 197: buy 1 unit at price 926.960022, total balance 9055.389953
# day 198, sell 1 unit at price 910.979980, investment -1.723919 %, total balance 9966.369933,
# day 203: buy 1 unit at price 921.280029, total balance 9045.089904
# day 205, sell 1 unit at price 913.809998, investment -0.810832 %, total balance 9958.899902,
# day 212: buy 1 unit at price 935.950012, total balance 9022.949890
# day 213, sell 1 unit at price 926.500000, investment -1.009671 %, total balance 9949.449890,
# day 226: buy 1 unit at price 944.489990, total balance 9004.959900
# day 227, sell 1 unit at price 949.500000, investment 0.530446 %, total balance 9954.459900,
# day 232: buy 1 unit at price 969.960022, total balance 8984.499878
# day 234, sell 1 unit at price 977.000000, investment 0.725801 %, total balance 9961.499878,

# %%
fig = plt.figure(figsize = (15,5))
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.show()
