# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# Out:
# /home/manmeet/anaconda3/envs/drl/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/manmeet/anaconda3/envs/drl/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/manmeet/anaconda3/envs/drl/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/manmeet/anaconda3/envs/drl/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/manmeet/anaconda3/envs/drl/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/manmeet/anaconda3/envs/drl/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /home/manmeet/anaconda3/envs/drl/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/manmeet/anaconda3/envs/drl/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/manmeet/anaconda3/envs/drl/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/manmeet/anaconda3/envs/drl/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/manmeet/anaconda3/envs/drl/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/manmeet/anaconda3/envs/drl/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
df = pd.read_csv('../dataset/GOOG-year.csv')
df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2016-11-02  778.200012  781.650024  763.450012  768.700012  768.700012
# 1  2016-11-03  767.250000  769.950012  759.030029  762.130005  762.130005
# 2  2016-11-04  750.659973  770.359985  750.560974  762.020020  762.020020
# 3  2016-11-07  774.500000  785.190002  772.549988  782.520020  782.520020
# 4  2016-11-08  783.400024  795.632996  780.190002  790.510010  790.510010
#
#     Volume
# 0  1872400
# 1  1943200
# 2  2134800
# 3  1585100
# 4  1350800

# %%
class Agent:

    LEARNING_RATE = 1e-4
    LAYER_SIZE = 256
    GAMMA = 0.9
    OUTPUT_SIZE = 3

    def __init__(self, state_size, window_size, trend, skip):
        self.state_size = state_size
        self.window_size = window_size
        self.half_window = window_size // 2
        self.trend = trend
        self.skip = skip
        self.X = tf.placeholder(tf.float32, (None, self.state_size))
        self.REWARDS = tf.placeholder(tf.float32, (None))
        self.ACTIONS = tf.placeholder(tf.int32, (None))
        feed_forward = tf.layers.dense(self.X, self.LAYER_SIZE, activation = tf.nn.relu)
        self.logits = tf.layers.dense(feed_forward, self.OUTPUT_SIZE, activation = tf.nn.softmax)
        input_y = tf.one_hot(self.ACTIONS, self.OUTPUT_SIZE)
        loglike = tf.log((input_y * (input_y - self.logits) + (1 - input_y) * (input_y + self.logits)) + 1)
        rewards = tf.tile(tf.reshape(self.REWARDS, (-1,1)), [1, self.OUTPUT_SIZE])
        self.cost = -tf.reduce_mean(loglike * (rewards + 1)) 
        self.optimizer = tf.train.AdamOptimizer(learning_rate = self.LEARNING_RATE).minimize(self.cost)
        self.sess = tf.InteractiveSession()
        self.sess.run(tf.global_variables_initializer())
    
    def predict(self, inputs):
        return self.sess.run(self.logits, feed_dict={self.X:inputs})
    
    def get_state(self, t):
        window_size = self.window_size + 1
        d = t - window_size + 1
        block = self.trend[d : t + 1] if d >= 0 else -d * [self.trend[0]] + self.trend[0 : t + 1]
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])
        return np.array([res])
    
    def discount_rewards(self, r):
        discounted_r = np.zeros_like(r)
        running_add = 0
        for t in reversed(range(0, r.size)):
            running_add = running_add * self.GAMMA + r[t]
            discounted_r[t] = running_add
        return discounted_r
    
    def get_predicted_action(self, sequence):
        prediction = self.predict(np.array(sequence))[0]
        return np.argmax(prediction)
    
    def buy(self, initial_money):
        starting_money = initial_money
        states_sell = []
        states_buy = []
        inventory = []
        state = self.get_state(0)
        for t in range(0, len(self.trend) - 1, self.skip):
            action = self.get_predicted_action(state)
            next_state = self.get_state(t + 1)
            
            if action == 1 and initial_money >= self.trend[t] and t < (len(self.trend) - self.half_window):
                inventory.append(self.trend[t])
                initial_money -= self.trend[t]
                states_buy.append(t)
                print('day %d: buy 1 unit at price %f, total balance %f'% (t, self.trend[t], initial_money))
                
                
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                initial_money += self.trend[t]
                states_sell.append(t)
                try:
                    invest = ((close[t] - bought_price) / bought_price) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell 1 unit at price %f, investment %f %%, total balance %f,'
                    % (t, close[t], invest, initial_money)
                )
            
            state = next_state
        invest = ((initial_money - starting_money) / starting_money) * 100
        total_gains = initial_money - starting_money
        return states_buy, states_sell, total_gains, invest
        
    
    def train(self, iterations, checkpoint, initial_money):
        for i in range(iterations):
            ep_history = []
            total_profit = 0
            inventory = []
            state = self.get_state(0)
            starting_money = initial_money
            for t in range(0, len(self.trend) - 1, self.skip):
                action = self.get_predicted_action(state)
                next_state = self.get_state(t + 1)
                if action == 1 and starting_money >= self.trend[t] and t < (len(self.trend) - self.half_window):
                    inventory.append(self.trend[t])
                    starting_money -= close[t]
                
                elif action == 2 and len(inventory):
                    bought_price = inventory.pop(0)
                    total_profit += self.trend[t] - bought_price
                    starting_money += self.trend[t]
                ep_history.append([state,action,starting_money,next_state])
                state = next_state
            ep_history = np.array(ep_history)
            ep_history[:,2] = self.discount_rewards(ep_history[:,2])
            cost, _ = self.sess.run([self.cost, self.optimizer], feed_dict={self.X:np.vstack(ep_history[:,0]),
                                                    self.REWARDS:ep_history[:,2],
                                                    self.ACTIONS:ep_history[:,1]})
            if (i+1) % checkpoint == 0:
                print('epoch: %d, total rewards: %f.3, cost: %f, total money: %f'%(i + 1, total_profit, cost,
                                                                                  starting_money))

# %%
close = df.Close.values.tolist()
initial_money = 10000
window_size = 30
skip = 1
agent = Agent(state_size = window_size,
             window_size = window_size,
             trend = close,
             skip = skip)
agent.train(iterations = 200, checkpoint = 10, initial_money = initial_money)
# Out:
# WARNING:tensorflow:From <ipython-input-3-46892b33829f>:17: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dense instead.
# WARNING:tensorflow:From /home/manmeet/anaconda3/envs/drl/lib/python3.6/site-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# /home/manmeet/anaconda3/envs/drl/lib/python3.6/site-packages/ipykernel_launcher.py:107: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# epoch: 10, total rewards: 1522.714782.3, cost: -2337.730957, total money: 4123.804747
# epoch: 20, total rewards: 1806.614930.3, cost: -1857.596802, total money: 3475.774842
# epoch: 30, total rewards: 1510.624814.3, cost: -2482.034912, total money: 3168.094723
# epoch: 40, total rewards: 1715.429686.3, cost: -2260.192139, total money: 2455.709592
# epoch: 50, total rewards: 1770.649901.3, cost: -2455.679443, total money: 3440.969847
# epoch: 60, total rewards: 1947.569700.3, cost: -1958.150513, total money: 3647.939694
# epoch: 70, total rewards: 2101.654661.3, cost: -2196.896973, total money: 3762.874692
# epoch: 80, total rewards: 2055.299803.3, cost: -2002.644043, total money: 1806.279783
# epoch: 90, total rewards: 1828.809815.3, cost: -2719.117676, total money: 3467.809875
# epoch: 100, total rewards: 1624.914916.3, cost: -3534.523193, total money: 2265.274962
# epoch: 110, total rewards: 2001.959958.3, cost: -2485.528076, total money: 2647.439998
# epoch: 120, total rewards: 1936.250186.3, cost: -3410.479492, total money: 2553.340272
# epoch: 130, total rewards: 1869.664855.3, cost: -3230.263184, total money: 2529.714902
# epoch: 140, total rewards: 1677.010070.3, cost: -4489.586426, total money: 3342.880065
# epoch: 150, total rewards: 1967.149777.3, cost: -3432.750732, total money: 3580.829829
# epoch: 160, total rewards: 1666.044552.3, cost: -5121.364746, total money: 2380.714535
# epoch: 170, total rewards: 1740.614927.3, cost: -5565.200195, total money: 3367.484982
# epoch: 180, total rewards: 1858.675049.3, cost: -5134.477539, total money: 3469.235168
# epoch: 190, total rewards: 740.264952.3, cost: -10170.868164, total money: 3157.184996
# epoch: 200, total rewards: 1774.229857.3, cost: -4638.530762, total money: 1487.619933

# %%
states_buy, states_sell, total_gains, invest = agent.buy(initial_money = initial_money)
# Out:
# day 0: buy 1 unit at price 768.700012, total balance 9231.299988
# day 1, sell 1 unit at price 762.130005, investment -0.854691 %, total balance 9993.429993,
# day 4: buy 1 unit at price 790.510010, total balance 9202.919983
# day 5: buy 1 unit at price 785.309998, total balance 8417.609985
# day 7: buy 1 unit at price 754.020020, total balance 7663.589965
# day 10, sell 1 unit at price 764.479980, investment -3.292815 %, total balance 8428.069945,
# day 11: buy 1 unit at price 771.229980, total balance 7656.839965
# day 14: buy 1 unit at price 768.270020, total balance 6888.569945
# day 15: buy 1 unit at price 760.989990, total balance 6127.579955
# day 17: buy 1 unit at price 768.239990, total balance 5359.339965
# day 18: buy 1 unit at price 770.840027, total balance 4588.499938
# day 21, sell 1 unit at price 750.500000, investment -4.432644 %, total balance 5338.999938,
# day 22: buy 1 unit at price 762.520020, total balance 4576.479918
# day 24: buy 1 unit at price 771.190002, total balance 3805.289916
# day 25, sell 1 unit at price 776.419983, investment 2.970738 %, total balance 4581.709899,
# day 26: buy 1 unit at price 789.289978, total balance 3792.419921
# day 29, sell 1 unit at price 797.070007, investment 3.350496 %, total balance 4589.489928,
# day 30, sell 1 unit at price 797.849976, investment 3.850203 %, total balance 5387.339904,
# day 32: buy 1 unit at price 794.200012, total balance 4593.139892
# day 34: buy 1 unit at price 794.559998, total balance 3798.579894
# day 36: buy 1 unit at price 789.909973, total balance 3008.669921
# day 39: buy 1 unit at price 782.789978, total balance 2225.879943
# day 40, sell 1 unit at price 771.820007, investment 1.423148 %, total balance 2997.699950,
# day 41, sell 1 unit at price 786.140015, investment 2.330004 %, total balance 3783.839965,
# day 43, sell 1 unit at price 794.020020, investment 3.007108 %, total balance 4577.859985,
# day 44, sell 1 unit at price 806.150024, investment 5.721818 %, total balance 5384.010009,
# day 45: buy 1 unit at price 806.650024, total balance 4577.359985
# day 47: buy 1 unit at price 807.909973, total balance 3769.450012
# day 49, sell 1 unit at price 807.880005, investment 4.757583 %, total balance 4577.330017,
# day 52, sell 1 unit at price 802.174988, investment 1.632481 %, total balance 5379.505005,
# day 53: buy 1 unit at price 805.020020, total balance 4574.484985
# day 55: buy 1 unit at price 823.869995, total balance 3750.614990
# day 56, sell 1 unit at price 835.669983, investment 5.221603 %, total balance 4586.284973,
# day 57: buy 1 unit at price 832.150024, total balance 3754.134949
# day 58: buy 1 unit at price 823.309998, total balance 2930.824951
# day 59: buy 1 unit at price 802.320007, total balance 2128.504944
# day 61, sell 1 unit at price 795.695007, investment 0.142847 %, total balance 2924.199951,
# day 62: buy 1 unit at price 798.530029, total balance 2125.669922
# day 63, sell 1 unit at price 801.489990, investment 1.465992 %, total balance 2927.159912,
# day 65, sell 1 unit at price 806.969971, investment 3.088950 %, total balance 3734.129883,
# day 66: buy 1 unit at price 808.380005, total balance 2925.749878
# day 68, sell 1 unit at price 813.669983, investment 0.870261 %, total balance 3739.419861,
# day 69: buy 1 unit at price 819.239990, total balance 2920.179871
# day 70: buy 1 unit at price 820.450012, total balance 2099.729859
# day 71: buy 1 unit at price 818.979980, total balance 1280.749879
# day 73: buy 1 unit at price 828.070007, total balance 452.679872
# day 75, sell 1 unit at price 830.760010, investment 2.828290 %, total balance 1283.439882,
# day 77, sell 1 unit at price 828.640015, investment 2.934088 %, total balance 2112.079897,
# day 78, sell 1 unit at price 829.280029, investment 0.656661 %, total balance 2941.359926,
# day 79: buy 1 unit at price 823.210022, total balance 2118.149904
# day 80: buy 1 unit at price 835.239990, total balance 1282.909914
# day 81: buy 1 unit at price 830.630005, total balance 452.279909
# day 82, sell 1 unit at price 829.080017, investment -0.368925 %, total balance 1281.359926,
# day 83: buy 1 unit at price 827.780029, total balance 453.579897
# day 84, sell 1 unit at price 831.909973, investment 1.044561 %, total balance 1285.489870,
# day 86: buy 1 unit at price 838.679993, total balance 446.809877
# day 88, sell 1 unit at price 845.539978, investment 5.386874 %, total balance 1292.349855,
# day 89, sell 1 unit at price 845.619995, investment 5.897081 %, total balance 2137.969850,
# day 90: buy 1 unit at price 847.200012, total balance 1290.769838
# day 92, sell 1 unit at price 852.119995, investment 5.410820 %, total balance 2142.889833,
# day 95: buy 1 unit at price 829.590027, total balance 1313.299806
# day 96, sell 1 unit at price 817.580017, investment -0.202624 %, total balance 2130.879823,
# day 97: buy 1 unit at price 814.429993, total balance 1316.449830
# day 98: buy 1 unit at price 819.510010, total balance 496.939820
# day 99, sell 1 unit at price 820.919983, investment 0.057282 %, total balance 1317.859803,
# day 100: buy 1 unit at price 831.409973, total balance 486.449830
# day 107, sell 1 unit at price 824.669983, investment 0.694767 %, total balance 1311.119813,
# day 108, sell 1 unit at price 824.729980, investment -0.403351 %, total balance 2135.849793,
# day 109: buy 1 unit at price 823.349976, total balance 1312.499817
# day 111: buy 1 unit at price 823.559998, total balance 488.939819
# day 129, sell 1 unit at price 928.780029, investment 12.824189 %, total balance 1417.719848,
# day 130: buy 1 unit at price 930.599976, total balance 487.119872
# day 131, sell 1 unit at price 932.219971, investment 11.611032 %, total balance 1419.339843,
# day 132: buy 1 unit at price 937.080017, total balance 482.259826
# day 133, sell 1 unit at price 943.000000, investment 13.528285 %, total balance 1425.259826,
# day 134: buy 1 unit at price 919.619995, total balance 505.639831
# day 136, sell 1 unit at price 934.010010, investment 12.833117 %, total balance 1439.649841,
# day 139, sell 1 unit at price 954.960022, investment 13.864648 %, total balance 2394.609863,
# day 141: buy 1 unit at price 971.469971, total balance 1423.139892
# day 143: buy 1 unit at price 964.859985, total balance 458.279907
# day 152, sell 1 unit at price 953.400024, investment 12.535412 %, total balance 1411.679931,
# day 155: buy 1 unit at price 939.780029, total balance 471.899902
# day 158, sell 1 unit at price 959.450012, investment 15.653513 %, total balance 1431.349914,
# day 160: buy 1 unit at price 965.590027, total balance 465.759887
# day 165, sell 1 unit at price 908.729980, investment 11.578649 %, total balance 1374.489867,
# day 166, sell 1 unit at price 898.700012, investment 9.663091 %, total balance 2273.189879,
# day 169: buy 1 unit at price 918.590027, total balance 1354.599852
# day 170: buy 1 unit at price 928.799988, total balance 425.799864
# day 178, sell 1 unit at price 968.150024, investment 16.446766 %, total balance 1393.949888,
# day 181: buy 1 unit at price 950.700012, total balance 443.249876
# day 182, sell 1 unit at price 947.799988, investment 15.115081 %, total balance 1391.049864,
# day 183: buy 1 unit at price 934.090027, total balance 456.959837
# day 186, sell 1 unit at price 930.830017, investment 13.025161 %, total balance 1387.789854,
# day 187, sell 1 unit at price 930.390015, investment -0.022562 %, total balance 2318.179869,
# day 188: buy 1 unit at price 923.650024, total balance 1394.529845
# day 190: buy 1 unit at price 929.359985, total balance 465.169860
# day 194, sell 1 unit at price 914.390015, investment -2.421352 %, total balance 1379.559875,
# day 196: buy 1 unit at price 922.219971, total balance 457.339904
# day 211, sell 1 unit at price 927.809998, investment 0.890586 %, total balance 1385.149902,
# day 212: buy 1 unit at price 935.950012, total balance 449.199890
# day 214, sell 1 unit at price 929.080017, investment -4.363486 %, total balance 1378.279907,
# day 215: buy 1 unit at price 932.070007, total balance 446.209900
# day 218, sell 1 unit at price 920.289978, investment -4.619324 %, total balance 1366.499878,
# day 219: buy 1 unit at price 915.000000, total balance 451.499878
# day 220, sell 1 unit at price 921.809998, investment -1.912153 %, total balance 1373.309876,
# day 221, sell 1 unit at price 931.580017, investment -3.522200 %, total balance 2304.889893,
# day 223, sell 1 unit at price 928.530029, investment 1.082093 %, total balance 3233.419922,
# day 226: buy 1 unit at price 944.489990, total balance 2288.929932
# day 228, sell 1 unit at price 959.109985, investment 3.263350 %, total balance 3248.039917,
# day 230: buy 1 unit at price 957.789978, total balance 2290.249939
# day 231: buy 1 unit at price 951.679993, total balance 1338.569946
# day 234: buy 1 unit at price 977.000000, total balance 361.569946
# day 243, sell 1 unit at price 988.200012, investment 3.944462 %, total balance 1349.769958,

# %%
fig = plt.figure(figsize = (15,5))
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.show()
